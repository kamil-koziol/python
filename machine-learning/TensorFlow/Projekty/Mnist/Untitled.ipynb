# %%
import tensorflow as tf
import tensorflow.keras as keras
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
dataset = keras.datasets.mnist

# %%
(train_images, train_labels), (test_images, test_labels) = dataset.load_data()

# %%
# Normalizacja danych
train_images = train_images/255
test_images = test_images/255

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape = (28,28)),
    keras.layers.Dense(256, activation=tf.nn.relu),
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])

# %%
model.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.SparseCategoricalCrossentropy(),
    metrics=["accuracy"]
)

# %%
model.fit(train_images, train_labels, epochs=8)
# Out:
# Train on 60000 samples
# Epoch 1/8
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x1684c18c0> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x1684c18c0> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# 60000/60000 [==============================] - 5s 81us/sample - loss: 0.2018 - accuracy: 0.9391
# Epoch 2/8
# ...

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
# Out:
# 10000/1 [=============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# ...

# %%
print(test_loss, test_acc)
# Out:
# 0.1281606942503271 0.9727

# %%
predictions = model.predict(test_images)

# %%
def predictionPercentages(array):
    for i,neuron in enumerate(array[0]):
        print(i,"=", neuron,"%")

# %%
def prepareImage(path):
    imgArray = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    return imgArray/255

# %%
image = prepareImage("./Mnist/obrazek.png")
image = np.array([image])

# %%
prediction = model.predict(image)
for i,result in enumerate(prediction[0]):
    print(i,round(result,5))
# Out:
# 0 0.0
# 1 7e-05
# 2 0.00098
# 3 0.77563
# 4 0.0
# 5 0.03064
# 6 0.0
# 7 0.0
# 8 0.01392
# 9 0.17875
